# %%
from google.colab import drive
drive.mount('/content/drive')
TrainingImagePath='/content/drive/My Drive/BTL_TTNT/data_train'
# Out:
# Mounted at /content/drive

# %%
import os
import PIL
from numpy import  asarray,array,uint8
import matplotlib.pyplot as plt
import numpy as np

#đếm 
def load_data(PATH):
  lables,totals=os.listdir(PATH),[]
  for label in lables:
    totals.append(len(os.listdir(os.path.join(PATH,label))))
  return lables,totals
    
X,Y = load_data(TrainingImagePath)

#import seaborn as sns dùng là xong
print(X)
# Out:
# ['face2', 'face1', 'face6', 'face5', 'face3', 'face4']

# %%
bars = plt.bar(X,Y)
plt.figure(figsize=(200,200))

# %% [markdown]
# số ảnh max là 41, số ảnh min là 25
# vì data quá ít nên phải Generator để tăng số lượng ảnh lên nhằm tăng độ chính xác của model

# %%
from keras.preprocessing.image import ImageDataGenerator

# xác định train_data
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=False)

# tạo Training Data 
training_set = train_datagen.flow_from_directory(
        TrainingImagePath,
        target_size=(224, 224),
        batch_size=16,
        class_mode='categorical')

# tạo Testing Data
test_datagen = ImageDataGenerator() # tăng ảnh lên
test_set = test_datagen.flow_from_directory(
        TrainingImagePath,
        target_size=(224, 224),
        batch_size=16,
        class_mode='categorical')

# các labels cho từng mặt
training_set.class_indices

test_set.class_indices
# Out:
# Found 195 images belonging to 6 classes.
# Found 195 images belonging to 6 classes.
# {'face1': 0, 'face2': 1, 'face3': 2, 'face4': 3, 'face5': 4, 'face6': 5}

# %%
for _ in range(5):
    img, label = training_set.next()
    print(img.shape)   #  (1,256,256,3)
    plt.imshow(img[0])
    plt.show()
# Out:
# (16, 224, 224, 3)
# (16, 224, 224, 3)
# (16, 224, 224, 3)
# (16, 224, 224, 3)
# (16, 224, 224, 3)

# %%
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, Model, optimizers
import numpy as np
model = Sequential()
model.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=6, activation="softmax")) # cần 
model.summary()
"""
folders = glob("")
model.add(Dense(len(folders), activation='softmax'))
"""
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 64)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 6)                 24582
#
# =================================================================
# Total params: 134,285,126
# Trainable params: 134,285,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import layers, models, Model, optimizers
from tensorflow.keras.callbacks import TensorBoard
learning_rate= 6e-5 #5e-5
"adam"
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adam(lr=learning_rate), metrics=["accuracy"])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from keras.callbacks import ModelCheckpoint

import time
#thời gian train
StartTime=time.time()

# Tạo callback

filepath="checkpoint.hdf5" # nó lưu lại kết quả tốt nhất 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')

# bắt đầu train model 
history = model.fit(training_set, epochs=20, validation_data=test_set, shuffle=True, callbacks=[checkpoint],verbose=1)

EndTime=time.time()
print("###### Total Time Taken: ", round((EndTime-StartTime)/60), 'Minutes ######')
# Out:
# Epoch 1/20
# 13/13 [==============================] - ETA: 0s - loss: 1.7887 - accuracy: 0.2103
# Epoch 00001: val_accuracy improved from -inf to 0.21026, saving model to checkpoint.hdf5
# 13/13 [==============================] - 39s 3s/step - loss: 1.7887 - accuracy: 0.2103 - val_loss: 12.4169 - val_accuracy: 0.2103
# Epoch 2/20
# 13/13 [==============================] - ETA: 0s - loss: 1.7759 - accuracy: 0.1949
# Epoch 00002: val_accuracy did not improve from 0.21026
# 13/13 [==============================] - 5s 413ms/step - loss: 1.7759 - accuracy: 0.1949 - val_loss: 43.3492 - val_accuracy: 0.2103
# Epoch 3/20
# 13/13 [==============================] - ETA: 0s - loss: 1.7660 - accuracy: 0.2103
# Epoch 00003: val_accuracy did not improve from 0.21026
# 13/13 [==============================] - 4s 339ms/step - loss: 1.7660 - accuracy: 0.2103 - val_loss: 6.6078 - val_accuracy: 0.2103
# Epoch 4/20
# 13/13 [==============================] - ETA: 0s - loss: 1.7757 - accuracy: 0.2103
# Epoch 00004: val_accuracy improved from 0.21026 to 0.31795, saving model to checkpoint.hdf5
# 13/13 [==============================] - 26s 2s/step - loss: 1.7757 - accuracy: 0.2103 - val_loss: 60.0593 - val_accuracy: 0.3179
# Epoch 5/20
# 13/13 [==============================] - ETA: 0s - loss: 1.7544 - accuracy: 0.2256
# Epoch 00005: val_accuracy did not improve from 0.31795
# 13/13 [==============================] - 5s 385ms/step - loss: 1.7544 - accuracy: 0.2256 - val_loss: 139.1398 - val_accuracy: 0.3077
# Epoch 6/20
# 13/13 [==============================] - ETA: 0s - loss: 1.7523 - accuracy: 0.2410
# Epoch 00006: val_accuracy did not improve from 0.31795
# 13/13 [==============================] - 4s 337ms/step - loss: 1.7523 - accuracy: 0.2410 - val_loss: 12.6914 - val_accuracy: 0.2462
# Epoch 7/20
# 13/13 [==============================] - ETA: 0s - loss: 1.6445 - accuracy: 0.3026
# Epoch 00007: val_accuracy improved from 0.31795 to 0.39487, saving model to checkpoint.hdf5
# 13/13 [==============================] - 27s 2s/step - loss: 1.6445 - accuracy: 0.3026 - val_loss: 90.5726 - val_accuracy: 0.3949
# Epoch 8/20
# 13/13 [==============================] - ETA: 0s - loss: 1.4994 - accuracy: 0.3231
# Epoch 00008: val_accuracy did not improve from 0.39487
# 13/13 [==============================] - 5s 335ms/step - loss: 1.4994 - accuracy: 0.3231 - val_loss: 163.7697 - val_accuracy: 0.3692
# Epoch 9/20
# 13/13 [==============================] - ETA: 0s - loss: 1.3932 - accuracy: 0.4872
# Epoch 00009: val_accuracy improved from 0.39487 to 0.46154, saving model to checkpoint.hdf5
# 13/13 [==============================] - 17s 1s/step - loss: 1.3932 - accuracy: 0.4872 - val_loss: 100.8587 - val_accuracy: 0.4615
# Epoch 10/20
# 13/13 [==============================] - ETA: 0s - loss: 1.3308 - accuracy: 0.5590
# Epoch 00010: val_accuracy did not improve from 0.46154
# 13/13 [==============================] - 5s 342ms/step - loss: 1.3308 - accuracy: 0.5590 - val_loss: 161.9858 - val_accuracy: 0.3538
# Epoch 11/20
# 13/13 [==============================] - ETA: 0s - loss: 1.2132 - accuracy: 0.5641
# Epoch 00011: val_accuracy improved from 0.46154 to 0.55897, saving model to checkpoint.hdf5
# 13/13 [==============================] - 29s 2s/step - loss: 1.2132 - accuracy: 0.5641 - val_loss: 169.6822 - val_accuracy: 0.5590
# Epoch 12/20
# 13/13 [==============================] - ETA: 0s - loss: 0.9053 - accuracy: 0.6513
# Epoch 00012: val_accuracy improved from 0.55897 to 0.62051, saving model to checkpoint.hdf5
# 13/13 [==============================] - 39s 3s/step - loss: 0.9053 - accuracy: 0.6513 - val_loss: 103.2354 - val_accuracy: 0.6205
# Epoch 13/20
# 13/13 [==============================] - ETA: 0s - loss: 0.9943 - accuracy: 0.6410
# Epoch 00013: val_accuracy improved from 0.62051 to 0.72821, saving model to checkpoint.hdf5
# 13/13 [==============================] - 35s 3s/step - loss: 0.9943 - accuracy: 0.6410 - val_loss: 90.4079 - val_accuracy: 0.7282
# Epoch 14/20
# 13/13 [==============================] - ETA: 0s - loss: 0.9202 - accuracy: 0.7282
# Epoch 00014: val_accuracy did not improve from 0.72821
# 13/13 [==============================] - 5s 342ms/step - loss: 0.9202 - accuracy: 0.7282 - val_loss: 42.5076 - val_accuracy: 0.6513
# Epoch 15/20
# 13/13 [==============================] - ETA: 0s - loss: 0.8055 - accuracy: 0.7846
# Epoch 00015: val_accuracy improved from 0.72821 to 0.76923, saving model to checkpoint.hdf5
# 13/13 [==============================] - 23s 2s/step - loss: 0.8055 - accuracy: 0.7846 - val_loss: 138.0155 - val_accuracy: 0.7692
# Epoch 16/20
# 13/13 [==============================] - ETA: 0s - loss: 0.5776 - accuracy: 0.7744
# Epoch 00016: val_accuracy did not improve from 0.76923
# 13/13 [==============================] - 5s 344ms/step - loss: 0.5776 - accuracy: 0.7744 - val_loss: 47.7125 - val_accuracy: 0.7538
# Epoch 17/20
# 13/13 [==============================] - ETA: 0s - loss: 0.5066 - accuracy: 0.7795
# Epoch 00017: val_accuracy improved from 0.76923 to 0.81026, saving model to checkpoint.hdf5
# 13/13 [==============================] - 33s 3s/step - loss: 0.5066 - accuracy: 0.7795 - val_loss: 72.1480 - val_accuracy: 0.8103
# Epoch 18/20
# 13/13 [==============================] - ETA: 0s - loss: 0.3969 - accuracy: 0.8667
# Epoch 00018: val_accuracy improved from 0.81026 to 0.88205, saving model to checkpoint.hdf5
# 13/13 [==============================] - 36s 3s/step - loss: 0.3969 - accuracy: 0.8667 - val_loss: 38.8130 - val_accuracy: 0.8821
# Epoch 19/20
# 13/13 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.8923
# Epoch 00019: val_accuracy improved from 0.88205 to 0.89231, saving model to checkpoint.hdf5
# 13/13 [==============================] - 35s 3s/step - loss: 0.3087 - accuracy: 0.8923 - val_loss: 41.8743 - val_accuracy: 0.8923
# Epoch 20/20
# 13/13 [==============================] - ETA: 0s - loss: 0.2009 - accuracy: 0.9231
# Epoch 00020: val_accuracy did not improve from 0.89231
# 13/13 [==============================] - 5s 350ms/step - loss: 0.2009 - accuracy: 0.9231 - val_loss: 51.7768 - val_accuracy: 0.8667
# ###### Total Time Taken:  7 Minutes ######

# %%
plt.plot(history.history['loss'], label='loss' )
plt.plot(history.history['accuracy'], label='accuracy')
plt.title('Bảng loss vs accuracy ')
plt.ylabel('value')
plt.xlabel('epoch')
plt.legend(loc="upper left")
plt.show()

# %%
plt.plot(history.history['val_accuracy'], label='validation_accuracy')
plt.plot(history.history['val_loss'], label='validation_loss')

# plt.title('validation accuracy ')
plt.ylabel('accuracy value')
plt.xlabel('No. epcoh')
plt.legend(loc="upper left")
plt.show()

# %%
# đánh giá độ chính xác của model
ac = model.evaluate(test_set)

print("test loss, test acc:",ac)

#predict để kiểm tra xem model dự đoán như thế nào
# Out:
# 13/13 [==============================] - 1s 68ms/step - loss: 51.7768 - accuracy: 0.8667
# test loss, test acc: [51.77679443359375, 0.8666666746139526]

# %%
model.save('/content/drive/My Drive/BTL_TTNT/model_vgg16.hdf5') #lưu model lại sau dùng

# %%
from google.colab import files
uploaded = files.upload()
widgets
# Out:
#      <input type="file" id="files-acf4fd73-53f8-4dd5-a70f-b574a9a835d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acf4fd73-53f8-4dd5-a70f-b574a9a835d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 31.png to 31 (1).png

# %%
from PIL import Image
img = plt.imread('31.png')
#img = img.resize(224, Image.ANTIALIAS)
plt.imshow(img)

img = img/255.0
img = np.expand_dims(img, axis=0)
#print(img)
print(img.shape)
# Out:
# (1, 224, 224, 3)

# %%
img_test = np.array(img)

#print(img_test)
#img_test =np.expand_dims(img_test, axis=0)
print(img_test.shape)

predictions = model.predict(img_test)

#argmax  lấy max ra 
print(predictions)
# Out:
# (1, 224, 224, 3)
# [[0.7734706  0.09121737 0.0035139  0.00091204 0.08183108 0.04905505]]

# %%
from PIL import Image

basewidth = 224
img = Image.open('31.png')
wpercent = (basewidth/float(img.size[0]))
hsize = int((float(img.size[1])*float(wpercent)))
img = img.resize((basewidth,hsize), Image.ANTIALIAS)
img.save('31.png')
